# %%
import numpy as np
import pandas as pd
mydata=pd.read_csv('crimes_against_women_2001-2014.csv')
mydata2=mydata.copy()

# %%
mydata.set_index('DISTRICT',inplace=True)
mydata=mydata.replace('TOTAL [a-bA-B]*','TOTAL',regex=True)
mydata=mydata.drop('TOTAL')

# %%
mydata.reset_index(inplace=True)
mydata.set_index('S.No.',inplace=True)

# %%
new_data= mydata.groupby('Year')
new_data

# %%
for Year, Year_mydata in new_data:
    print(Year)
    print(Year_mydata)
# Out:
# 2001
#             DISTRICT        STATE_UT  Year  Rape  Kidnapping and Abduction  \
# S.No.
# 0           ADILABAD  ANDHRA PRADESH  2001    50                        30
# 1          ANANTAPUR  ANDHRA PRADESH  2001    23                        30
# 2           CHITTOOR  ANDHRA PRADESH  2001    27                        34
# 3           CUDDAPAH  ANDHRA PRADESH  2001    20                        20
# 4      EAST GODAVARI  ANDHRA PRADESH  2001    23                        26
# ...              ...             ...   ...   ...                       ...
# 709            SOUTH           DELHI  2001    65                       170
# 710       SOUTH WEST           DELHI  2001    42                       113
# 711             WEST           DELHI  2001    45                        99
# 712      LAKSHADWEEP     LAKSHADWEEP  2001     0                         0
# 714      PONDICHERRY      PUDUCHERRY  2001     9                         3
#
# ...

# %%
 for i in range(2001,2015):
    globals()['new_data_%s' % i] = new_data.get_group(i)

# %%
new_data_2014
# Out:
#                 DISTRICT        STATE_UT  Year  Rape  \
# S.No.
# 0              Anantapur  Andhra Pradesh  2014    35
# 1               Chittoor  Andhra Pradesh  2014    32
# 2               Cuddapah  Andhra Pradesh  2014    28
# 3          East Godavari  Andhra Pradesh  2014    85
# 4       Guntakal Railway  Andhra Pradesh  2014     0
# ...                  ...             ...   ...   ...
# 832          Lakshadweep     Lakshadweep  2014     1
# 833    Total District(s)     Lakshadweep  2014     1
# 834             Karaikal      Puducherry  2014     3
# 835           Puducherry      Puducherry  2014     7
# 836    Total District(s)      Puducherry  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# S.No.
# 0                           106            25
# 1                            34            17
# 2                            16            16
# 3                            25             7
# 4                             0             0
# ...

# %%
new_data_group_2001 = new_data_2001.groupby('STATE_UT')
new_data_group_2002 = new_data_2002.groupby('STATE_UT')
new_data_group_2003 = new_data_2003.groupby('STATE_UT')
new_data_group_2004 = new_data_2004.groupby('STATE_UT')
new_data_group_2005 = new_data_2005.groupby('STATE_UT')
new_data_group_2006 = new_data_2006.groupby('STATE_UT')
new_data_group_2007 = new_data_2007.groupby('STATE_UT')
new_data_group_2008 = new_data_2008.groupby('STATE_UT')
new_data_group_2009 = new_data_2009.groupby('STATE_UT')
new_data_group_2010 = new_data_2010.groupby('STATE_UT')
new_data_group_2011 = new_data_2011.groupby('STATE_UT')
new_data_group_2012 = new_data_2012.groupby('STATE_UT')
new_data_group_2013 = new_data_2013.groupby('STATE_UT')
new_data_group_2014 = new_data_2014.groupby('STATE_UT')

# %%
my_total_data= mydata2[(mydata2['DISTRICT']=='TOTAL')]

# %%
new_data_total= my_total_data.groupby('Year')
new_data_total

# %%
 for i in range(2001,2014):
    if(i==2013 or i==2014):
        continue;
    globals()['new_data_total_%s' % i] = new_data_total.get_group(i)

# %%
edit_1=new_data.get_group(2014)
edit_1
# Out:
#                 DISTRICT        STATE_UT  Year  Rape  \
# S.No.
# 0              Anantapur  Andhra Pradesh  2014    35
# 1               Chittoor  Andhra Pradesh  2014    32
# 2               Cuddapah  Andhra Pradesh  2014    28
# 3          East Godavari  Andhra Pradesh  2014    85
# 4       Guntakal Railway  Andhra Pradesh  2014     0
# ...                  ...             ...   ...   ...
# 832          Lakshadweep     Lakshadweep  2014     1
# 833    Total District(s)     Lakshadweep  2014     1
# 834             Karaikal      Puducherry  2014     3
# 835           Puducherry      Puducherry  2014     7
# 836    Total District(s)      Puducherry  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# S.No.
# 0                           106            25
# 1                            34            17
# 2                            16            16
# 3                            25             7
# 4                             0             0
# ...

# %%
edit_2=edit_1.groupby('STATE_UT')
new_data_total_2014=edit_2.sum()
new_data_total_2014=new_data_total_2014.assign(Year=2014)
new_data_total_2014
# Out:
#                    Year   Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE_UT
# A & N Islands      2014     64                        34             6
# Andhra Pradesh     2014   1922                      1442           430
# Arunachal Pradesh  2014    166                       182             2
# Assam              2014   3960                      7790           376
# Bihar              2014   2254                      9470          2746
# Chandigarh         2014    118                       266             4
# Chhattisgarh       2014   2872                      2786           256
# D&N Haveli         2014     10                        14             0
# Daman & Diu        2014      4                         2             0
# Delhi UT           2014   4192                      8068           306
# Goa                2014    190                       172             0
# Gujarat            2014   1682                      4374            46
# ...

# %%
edit=new_data.get_group(2013)
edit
# Out:
#           DISTRICT        STATE_UT  Year  Rape  Kidnapping and Abduction  \
# S.No.
# 0         ADILABAD  Andhra Pradesh  2013    61                        47
# 1        ANANTAPUR  Andhra Pradesh  2013    28                        84
# 2         CHITTOOR  Andhra Pradesh  2013    31                        27
# 3         CUDDAPAH  Andhra Pradesh  2013    19                        50
# 4        CYBERABAD  Andhra Pradesh  2013   138                       129
# ...            ...             ...   ...   ...                       ...
# 818    LAKSHADWEEP     Lakshadweep  2013     2                         0
# 819       ZZ TOTAL     Lakshadweep  2013     2                         0
# 820       KARAIKAL      Puducherry  2013     6                         2
# 821     PUDUCHERRY      Puducherry  2013    11                        23
# 822       ZZ TOTAL      Puducherry  2013    17                        25
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# S.No.
# ...

# %%
edit2=edit.groupby('STATE_UT')
new_data_total_2013=edit2.sum()
new_data_total_2013=new_data_total_2013.assign(Year=2013)
new_data_total_2013
# Out:
#                    Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE_UT
# A&N Islands        2013    54                        24             2
# Andhra Pradesh     2013  3270                      3190           984
# Arunachal Pradesh  2013   150                       172             0
# Assam              2013  3874                      8444           340
# Bihar              2013  2256                      8838          2364
# Chandigarh         2013    90                       348             2
# Chhattisgarh       2013  2760                      3762           218
# D&N Haveli         2013    10                        22             0
# Daman & Diu        2013    16                        12             0
# Delhi UT           2013  3272                      7218           288
# Goa                2013   172                       140             0
# Gujarat            2013  1464                      4460            58
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
new_data_total_2013.reset_index(inplace=True)

# %%
new_data_total_2013.plot(x='STATE_UT',y='Rape',color='r',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Kidnapping and Abduction',color='g',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Dowry Deaths',color='b',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Assault on women with intent to outrage her modesty',color='k',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Insult to modesty of Women',color='m',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Cruelty by Husband or his Relatives',color='y',kind='bar',figsize=(20,10))
new_data_total_2013.plot(x='STATE_UT',y='Importation of Girls',color='c',kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='STATE_UT'>

# %%
x=new_data_total_2013['STATE_UT']
y1=new_data_total_2013['Rape']
y2=new_data_total_2013['Kidnapping and Abduction']
y3=new_data_total_2013['Dowry Deaths']
y4=new_data_total_2013['Assault on women with intent to outrage her modesty']
y5=new_data_total_2013['Insult to modesty of Women']
y6=new_data_total_2013['Cruelty by Husband or his Relatives']
y7=new_data_total_2013['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
new_data_total_2001.plot(x='STATE_UT',y='Rape',color='r',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Kidnapping and Abduction',color='g',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Dowry Deaths',color='b',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Assault on women with intent to outrage her modesty',color='k',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Insult to modesty of Women',color='m',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Cruelty by Husband or his Relatives',color='y',kind='bar',figsize=(20,10))
new_data_total_2001.plot(x='STATE_UT',y='Importation of Girls',color='c',kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='STATE_UT'>

# %%
x=new_data_total_2001['STATE_UT']
y1=new_data_total_2001['Rape']
y2=new_data_total_2001['Kidnapping and Abduction']
y3=new_data_total_2001['Dowry Deaths']
y4=new_data_total_2001['Assault on women with intent to outrage her modesty']
y5=new_data_total_2001['Insult to modesty of Women']
y6=new_data_total_2001['Cruelty by Husband or his Relatives']
y7=new_data_total_2001['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2002['STATE_UT']
y1=new_data_total_2002['Rape']
y2=new_data_total_2002['Kidnapping and Abduction']
y3=new_data_total_2002['Dowry Deaths']
y4=new_data_total_2002['Assault on women with intent to outrage her modesty']
y5=new_data_total_2002['Insult to modesty of Women']
y6=new_data_total_2002['Cruelty by Husband or his Relatives']
y7=new_data_total_2002['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2003['STATE_UT']
y1=new_data_total_2003['Rape']
y2=new_data_total_2003['Kidnapping and Abduction']
y3=new_data_total_2003['Dowry Deaths']
y4=new_data_total_2003['Assault on women with intent to outrage her modesty']
y5=new_data_total_2003['Insult to modesty of Women']
y6=new_data_total_2003['Cruelty by Husband or his Relatives']
y7=new_data_total_2003['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2004['STATE_UT']
y1=new_data_total_2004['Rape']
y2=new_data_total_2004['Kidnapping and Abduction']
y3=new_data_total_2004['Dowry Deaths']
y4=new_data_total_2004['Assault on women with intent to outrage her modesty']
y5=new_data_total_2004['Insult to modesty of Women']
y6=new_data_total_2004['Cruelty by Husband or his Relatives']
y7=new_data_total_2004['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2005['STATE_UT']
y1=new_data_total_2005['Rape']
y2=new_data_total_2005['Kidnapping and Abduction']
y3=new_data_total_2005['Dowry Deaths']
y4=new_data_total_2005['Assault on women with intent to outrage her modesty']
y5=new_data_total_2005['Insult to modesty of Women']
y6=new_data_total_2005['Cruelty by Husband or his Relatives']
y7=new_data_total_2005['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2006['STATE_UT']
y1=new_data_total_2006['Rape']
y2=new_data_total_2006['Kidnapping and Abduction']
y3=new_data_total_2006['Dowry Deaths']
y4=new_data_total_2006['Assault on women with intent to outrage her modesty']
y5=new_data_total_2006['Insult to modesty of Women']
y6=new_data_total_2006['Cruelty by Husband or his Relatives']
y7=new_data_total_2006['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2007['STATE_UT']
y1=new_data_total_2007['Rape']
y2=new_data_total_2007['Kidnapping and Abduction']
y3=new_data_total_2007['Dowry Deaths']
y4=new_data_total_2007['Assault on women with intent to outrage her modesty']
y5=new_data_total_2007['Insult to modesty of Women']
y6=new_data_total_2007['Cruelty by Husband or his Relatives']
y7=new_data_total_2007['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2008['STATE_UT']
y1=new_data_total_2008['Rape']
y2=new_data_total_2008['Kidnapping and Abduction']
y3=new_data_total_2008['Dowry Deaths']
y4=new_data_total_2008['Assault on women with intent to outrage her modesty']
y5=new_data_total_2008['Insult to modesty of Women']
y6=new_data_total_2008['Cruelty by Husband or his Relatives']
y7=new_data_total_2008['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
x=new_data_total_2009['STATE_UT']
y1=new_data_total_2009['Rape']
y2=new_data_total_2009['Kidnapping and Abduction']
y3=new_data_total_2009['Dowry Deaths']
y4=new_data_total_2009['Assault on women with intent to outrage her modesty']
y5=new_data_total_2009['Insult to modesty of Women']
y6=new_data_total_2009['Cruelty by Husband or his Relatives']
y7=new_data_total_2009['Importation of Girls']
plt.figure(figsize=(20,20))
plt.bar(x,y1,label='Rape',color='r')
plt.bar(x,y2,label='Kidnapping and Abduction',color='b')
plt.bar(x,y3,label='Dowry Deaths',color='k')
plt.bar(x,y4,label='Assault on women with intent to outrage her modesty',color='g')
plt.bar(x,y5,label='Insult to modesty of Women',color='y')
plt.bar(x,y6,label='Cruelty by Husband or his Relatives',color='m')
plt.bar(x,y7,label='Importation of Girls',color='c')

plt.xticks(rotation=90)
plt.legend()

# %%
total_2001=new_data_total_2001.sum()
total_2002=new_data_total_2002.sum()
total_2003=new_data_total_2003.sum()
total_2004=new_data_total_2004.sum()
total_2005=new_data_total_2005.sum()
total_2006=new_data_total_2006.sum()
total_2007=new_data_total_2007.sum()
total_2008=new_data_total_2008.sum()
total_2009=new_data_total_2009.sum()
total_2010=new_data_total_2010.sum()
total_2011=new_data_total_2011.sum()
total_2012=new_data_total_2012.sum()
total_2013=new_data_total_2013.sum()
total_2014=new_data_total_2014.sum()

# %%
x=range(2001,2015)
y1=[total_2001['Rape'],
total_2002['Rape'],
total_2003['Rape'],
total_2004['Rape'],
total_2005['Rape'],
total_2006['Rape'],
total_2007['Rape'],
total_2008['Rape'],
total_2009['Rape'],
total_2010['Rape'],
total_2011['Rape'],
total_2012['Rape'],
total_2013['Rape'],
total_2014['Rape']]
y2=[total_2001['Kidnapping and Abduction'],
total_2002['Kidnapping and Abduction'],
total_2003['Kidnapping and Abduction'],
total_2004['Kidnapping and Abduction'],
total_2005['Kidnapping and Abduction'],
total_2006['Kidnapping and Abduction'],
total_2007['Kidnapping and Abduction'],
total_2008['Kidnapping and Abduction'],
total_2009['Kidnapping and Abduction'],
total_2010['Kidnapping and Abduction'],
total_2011['Kidnapping and Abduction'],
total_2012['Kidnapping and Abduction'],
total_2013['Kidnapping and Abduction'],
total_2014['Kidnapping and Abduction']]
y3=[total_2001['Dowry Deaths'],
total_2002['Dowry Deaths'],
total_2003['Dowry Deaths'],
total_2004['Dowry Deaths'],
total_2005['Dowry Deaths'],
total_2006['Dowry Deaths'],
total_2007['Dowry Deaths'],
total_2008['Dowry Deaths'],
total_2009['Dowry Deaths'],
total_2010['Dowry Deaths'],
total_2011['Dowry Deaths'],
total_2012['Dowry Deaths'],
total_2013['Dowry Deaths'],
total_2014['Dowry Deaths']]
y4=[total_2001['Assault on women with intent to outrage her modesty'],
total_2002['Assault on women with intent to outrage her modesty'],
total_2003['Assault on women with intent to outrage her modesty'],
total_2004['Assault on women with intent to outrage her modesty'],
total_2005['Assault on women with intent to outrage her modesty'],
total_2006['Assault on women with intent to outrage her modesty'],
total_2007['Assault on women with intent to outrage her modesty'],
total_2008['Assault on women with intent to outrage her modesty'],
total_2009['Assault on women with intent to outrage her modesty'],
total_2010['Assault on women with intent to outrage her modesty'],
total_2011['Assault on women with intent to outrage her modesty'],
total_2012['Assault on women with intent to outrage her modesty'],
total_2013['Assault on women with intent to outrage her modesty'],
total_2014['Assault on women with intent to outrage her modesty']]
y5=[total_2001['Insult to modesty of Women'],
total_2002['Insult to modesty of Women'],
total_2003['Insult to modesty of Women'],
total_2004['Insult to modesty of Women'],
total_2005['Insult to modesty of Women'],
total_2006['Insult to modesty of Women'],
total_2007['Insult to modesty of Women'],
total_2008['Insult to modesty of Women'],
total_2009['Insult to modesty of Women'],
total_2010['Insult to modesty of Women'],
total_2011['Insult to modesty of Women'],
total_2012['Insult to modesty of Women'],
total_2013['Insult to modesty of Women'],
total_2014['Insult to modesty of Women']]
y6=[total_2001['Cruelty by Husband or his Relatives'],
total_2002['Cruelty by Husband or his Relatives'],
total_2003['Cruelty by Husband or his Relatives'],
total_2004['Cruelty by Husband or his Relatives'],
total_2005['Cruelty by Husband or his Relatives'],
total_2006['Cruelty by Husband or his Relatives'],
total_2007['Cruelty by Husband or his Relatives'],
total_2008['Cruelty by Husband or his Relatives'],
total_2009['Cruelty by Husband or his Relatives'],
total_2010['Cruelty by Husband or his Relatives'],
total_2011['Cruelty by Husband or his Relatives'],
total_2012['Cruelty by Husband or his Relatives'],
total_2013['Cruelty by Husband or his Relatives'],
total_2014['Cruelty by Husband or his Relatives']]
y7=[total_2001['Importation of Girls'],
total_2002['Importation of Girls'],
total_2003['Importation of Girls'],
total_2004['Importation of Girls'],
total_2005['Importation of Girls'],
total_2006['Importation of Girls'],
total_2007['Importation of Girls'],
total_2008['Importation of Girls'],
total_2009['Importation of Girls'],
total_2010['Importation of Girls'],
total_2011['Importation of Girls'],
total_2012['Importation of Girls'],
total_2013['Importation of Girls'],
total_2014['Importation of Girls']]
plt.figure(figsize=(20,10))
plt.plot(x,y1,label='Rape')
plt.plot(x,y2,label='Kidnapping and Abduction')
plt.plot(x,y3,label='Dowry Deaths')
plt.plot(x,y4,label='Assault on women with intent to outrage her modesty')
plt.plot(x,y5,label='Insult to modesty of Women')
plt.plot(x,y6,label='Cruelty by Husband or his Relatives')
plt.plot(x,y7,label='Importation of Girls')
plt.legend()

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()

# %%
rape=[total_2001['Rape'],
total_2002['Rape'],
total_2003['Rape'],
total_2004['Rape'],
total_2005['Rape'],
total_2006['Rape'],
total_2007['Rape'],
total_2008['Rape'],
total_2009['Rape'],
total_2010['Rape'],
total_2011['Rape'],
total_2012['Rape'],
total_2013['Rape'],
total_2014['Rape']]
year={
    'year':range(2001,2015),
    'rape':rape
}
df=pd.DataFrame(year)
reg.fit(df[['year']],df.rape)
# Out:
# LinearRegression()

# %%
reg.predict([[2015]])
# Out:
# array([50844.84615385])
